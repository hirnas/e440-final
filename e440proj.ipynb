# %%
import intake
import xarray as xr
import intake_esm
#url = intake_esm.tutorial.get_url('google_cmip6')
#print(url)
url ="https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"

# %%
cat = intake.open_esm_datastore(url)
cat
# Out:
# <p><strong>pangeo-cmip6 catalog with 7674 dataset(s) from 514818 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>700</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>514818</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>736</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat.df
# Out:
#        activity_id       institution_id      source_id       experiment_id  \
# 0       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 1       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 2       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 3       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 4       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# ...            ...                  ...            ...                 ...
# 514813        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514814        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514815        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514816        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 514817        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
#
#        member_id table_id variable_id grid_label  \
# 0       r1i1p1f1     Amon          ps         gn
# 1       r1i1p1f1     Amon        rsds         gn
# 2       r1i1p1f1     Amon        rlus         gn
# 3       r1i1p1f1     Amon        rlds         gn
# 4       r1i1p1f1     Amon         psl         gn
# ...          ...      ...         ...        ...
# 514813  r1i1p1f1     Amon         tas         gr
# 514814  r1i1p1f1     Amon        tauu         gr
# 514815  r1i1p1f1     Amon         hur         gr
# 514816  r1i1p1f1     Amon         hus         gr
# 514817  r1i1p1f1     Amon        tauv         gr
#
#                                                    zstore  dcpp_init_year  \
# 0       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 1       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 2       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 3       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# 4       gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN
# ...                                                   ...             ...
# 514813  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 514814  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 514815  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 514816  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
# 514817  gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-E...             NaN
#
#          version
# 0       20170706
# 1       20170706
# 2       20170706
# 3       20170706
# 4       20170706
# ...          ...
# 514813  20211207
# 514814  20211207
# 514815  20211207
# 514816  20211207
# 514817  20211207
#
# [514818 rows x 11 columns]

# %%
print(cat.unique()['activity_id'])
# Out:
# ['HighResMIP', 'CMIP', 'CFMIP', 'ScenarioMIP', 'AerChemMIP', 'RFMIP', 'FAFMIP', 'DAMIP', 'LUMIP', 'CDRMIP', 'GMMIP', 'C4MIP', 'OMIP', 'PMIP', 'LS3MIP', 'DCPP', 'PAMIP', 'ISMIP6']

# %%
ocat = cat_subset = cat.search(
    activity_id = 'OMIP'
)
ocat.df
# Out:
#     activity_id institution_id     source_id experiment_id member_id table_id  \
# 0          OMIP      NOAA-GFDL      GFDL-CM4         omip1  r1i1p1f1    SImon
# 1          OMIP      NOAA-GFDL      GFDL-CM4         omip1  r1i1p1f1    SImon
# 2          OMIP      NOAA-GFDL      GFDL-CM4         omip1  r1i1p1f1    SImon
# 3          OMIP      NOAA-GFDL      GFDL-CM4         omip1  r1i1p1f1    SImon
# 4          OMIP      NOAA-GFDL      GFDL-CM4         omip1  r1i1p1f1    SImon
# ..          ...            ...           ...           ...       ...      ...
# 311        OMIP           IPSL  IPSL-CM6A-LR         omip1  r1i1p1f2     Omon
# 312        OMIP           IPSL  IPSL-CM6A-LR         omip1  r2i1p1f2      Ofx
# 313        OMIP           IPSL  IPSL-CM6A-LR         omip1  r1i1p1f2     Omon
# 314        OMIP           IPSL  IPSL-CM6A-LR         omip1  r1i1p1f2     Omon
# 315        OMIP           IPSL  IPSL-CM6A-LR         omip1  r1i1p1f1     Omon
#
#     variable_id grid_label                                             zstore  \
# 0           siu         gn  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# 1         sivol         gn  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# 2        siconc         gr  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# 3        simass         gn  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# 4        simass         gr  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# ..          ...        ...                                                ...
# 311       intpp         gn  gs://cmip6/CMIP6/OMIP/IPSL/IPSL-CM6A-LR/omip1/...
# 312       basin         gn  gs://cmip6/CMIP6/OMIP/IPSL/IPSL-CM6A-LR/omip1/...
# 313       masso         gn  gs://cmip6/CMIP6/OMIP/IPSL/IPSL-CM6A-LR/omip1/...
# 314   masscello         gn  gs://cmip6/CMIP6/OMIP/IPSL/IPSL-CM6A-LR/omip1/...
# 315          wo         gn  gs://cmip6/CMIP6/OMIP/IPSL/IPSL-CM6A-LR/omip1/...
#
#      dcpp_init_year   version
# 0               NaN  20180701
# 1               NaN  20180701
# 2               NaN  20180701
# 3               NaN  20180701
# 4               NaN  20180701
# ..              ...       ...
# 311             NaN  20191120
# 312             NaN  20191120
# 313             NaN  20191120
# 314             NaN  20191120
# 315             NaN  20191120
#
# [316 rows x 11 columns]

# %%
ocat
# Out:
# <p><strong>pangeo-cmip6 catalog with 29 dataset(s) from 316 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>316</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ocat.unique()
# Out:
# activity_id                                                       [OMIP]
# institution_id         [NOAA-GFDL, CNRM-CERFACS, CAS, NCAR, MIROC, NC...
# source_id              [GFDL-CM4, GFDL-OM4p5B, CNRM-ESM2-1, CNRM-CM6-...
# experiment_id                                                    [omip1]
# member_id                       [r1i1p1f1, r1i1p1f2, r2i1p1f1, r2i1p1f2]
# table_id                                   [SImon, Omon, Oyr, Ofx, Oday]
# variable_id            [siu, sivol, siconc, simass, sisnconc, sisnmas...
# grid_label                                                      [gn, gr]
# zstore                 [gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip...
# dcpp_init_year                                                        []
# version                [20180701, 20190328, 20190729, 20190801, 20190...
# derived_variable_id                                                   []
# dtype: object

# %%
print(ocat.unique()['variable_id'])
# Out:
# ['siu', 'sivol', 'siconc', 'simass', 'sisnconc', 'sisnmass', 'sisnthick', 'sispeed', 'sitemptop', 'msftyz', 'o2', 'ph', 'po4', 'siv', 'volcello', 'areacello', 'cfc11', 'sitimefrac', 'cfc12', 'dissic', 'expc', 'fgco2', 'fgo2', 'intpp', 'mlotst', 'chl', 'sithick', 'hfds', 'icfriver', 'intpbfe', 'intpbp', 'intpcalcite', 'mlotstmax', 'graz', 'pp', 'so', 'sos', 'spco2', 'talk', 'thetao', 'mlotstmin', 'tos', 'dissoc', 'dpco2', 'dpo2', 'phyp', 'phyc', 'co3', 'co3satcalc', 'dfe', 'mlotstsq', 'deptho', 'basin', 'agessc', 'wo', 'vo', 'uo', 'intdic', 'no3', 'tauvo', 'masscello', 'masso', 'volo', 'vmo', 'tauuo', 'obvfsq', 'umo', 'thkcello', 'msftmz', 'sftof', 'phos', 'o2sat', 'zsatarag', 'msftbarot']

# %%
print(ocat.unique()['experiment_id'])
# Out:
# ['omip1']

# %%
ocat_chl = ocat.search(
    variable_id = 'chl'
)
ocat_chl.df
# Out:
#   activity_id institution_id    source_id experiment_id member_id table_id  \
# 0        OMIP      NOAA-GFDL  GFDL-OM4p5B         omip1  r1i1p1f1     Omon
# 1        OMIP      NOAA-GFDL     GFDL-CM4         omip1  r1i1p1f1     Omon
# 2        OMIP           NCAR        CESM2         omip1  r1i1p1f1     Omon
# 3        OMIP           NCAR        CESM2         omip1  r1i1p1f1     Omon
#
#   variable_id grid_label                                             zstore  \
# 0         chl         gr  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-OM4p5B/om...
# 1         chl         gr  gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1...
# 2         chl         gr  gs://cmip6/CMIP6/OMIP/NCAR/CESM2/omip1/r1i1p1f...
# 3         chl         gn  gs://cmip6/CMIP6/OMIP/NCAR/CESM2/omip1/r1i1p1f...
#
#    dcpp_init_year   version
# 0             NaN  20180701
# 1             NaN  20180701
# 2             NaN  20190802
# 3             NaN  20190802

# %%
dset_dict = ocat_chl.to_dataset_dict(
    xarray_open_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True}
)
dset_dict
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:29&lt;00:00]
#     </div>
# {'OMIP.NCAR.CESM2.omip1.Omon.gr': <xarray.Dataset>
#  Dimensions:           (member_id: 1, dcpp_init_year: 1, time: 3720,
#                         lev_partial: 8, lat: 180, lon: 360, d2: 2)
#  Coordinates:
#    * lat               (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#      lat_bnds          (lat, d2) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * lev_partial       (lev_partial) float64 0.0 10.0 20.0 ... 75.0 100.0 125.0
#      lev_partial_bnds  (lev_partial, d2) float64 dask.array<chunksize=(8, 2), meta=np.ndarray>
#    * lon               (lon) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#      lon_bnds          (lon, d2) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#    * time              (time) object 0001-01-15 13:00:00.999998 ... 0310-12-15...
#      time_bnds         (time, d2) object dask.array<chunksize=(3720, 2), meta=np.ndarray>
#    * member_id         (member_id) object 'r1i1p1f1'
#    * dcpp_init_year    (dcpp_init_year) float64 nan
#  Dimensions without coordinates: d2
#  Data variables:
#      chl               (member_id, dcpp_init_year, time, lev_partial, lat, lon) float32 dask.array<chunksize=(1, 1, 48, 8, 180, 360), meta=np.ndarray>
#  Attributes: (12/62)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      OMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            0.0
#      case_id:                          1541
#      ...                               ...
#      intake_esm_attrs:variable_id:     chl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://cmip6/CMIP6/OMIP/NCAR/CESM2/omip1/...
#      intake_esm_attrs:version:         20190802
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           OMIP.NCAR.CESM2.omip1.Omon.gr,
#  'OMIP.NCAR.CESM2.omip1.Omon.gn': <xarray.Dataset>
#  Dimensions:         (member_id: 1, dcpp_init_year: 1, time: 3720, lev: 15,
#                       nlat: 384, nlon: 320, vertices: 4, d2: 2)
#  Coordinates:
#      lat             (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#      lat_bnds        (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#    * lev             (lev) float64 500.0 1.5e+03 2.5e+03 ... 1.35e+04 1.45e+04
#      lev_bnds        (lev, d2) float32 dask.array<chunksize=(15, 2), meta=np.ndarray>
#      lon             (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#      lon_bnds        (nlat, nlon, vertices) float32 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#    * nlat            (nlat) int32 1 2 3 4 5 6 7 8 ... 378 379 380 381 382 383 384
#    * nlon            (nlon) int32 1 2 3 4 5 6 7 8 ... 314 315 316 317 318 319 320
#    * time            (time) object 0001-01-15 13:00:00.999998 ... 0310-12-15 1...
#      time_bnds       (time, d2) object dask.array<chunksize=(3720, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r1i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: vertices, d2
#  Data variables:
#      chl             (member_id, dcpp_init_year, time, lev, nlat, nlon) float32 dask.array<chunksize=(1, 1, 24, 15, 384, 320), meta=np.ndarray>
#  Attributes: (12/62)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      OMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            0.0
#      case_id:                          1541
#      ...                               ...
#      intake_esm_attrs:variable_id:     chl
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:zstore:          gs://cmip6/CMIP6/OMIP/NCAR/CESM2/omip1/...
#      intake_esm_attrs:version:         20190802
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           OMIP.NCAR.CESM2.omip1.Omon.gn,
#  'OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr': <xarray.Dataset>
#  Dimensions:         (member_id: 1, dcpp_init_year: 1, time: 3600, lev: 35,
#                       lat: 180, lon: 360, bnds: 2)
#  Coordinates:
#    * lat             (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * lev             (lev) float64 2.5 10.0 20.0 32.5 ... 5.5e+03 6e+03 6.5e+03
#      lev_bnds        (lev, bnds) float64 dask.array<chunksize=(35, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#    * time            (time) object 1708-01-16 12:00:00 ... 2007-12-16 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3600, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r1i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      chl             (member_id, dcpp_init_year, time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 24, 35, 180, 360), meta=np.ndarray>
#  Attributes: (12/60)
#      Conventions:                      CF-1.7 CMIP-6.0 UGRID-1.0
#      activity_id:                      OMIP
#      branch_method:                    none provided
#      branch_time_in_child:             0.0
#      comment:                          Experiment name = OM4p25_IAF_BLING_csf_...
#      contact:                          gfdl.climate.model.info@noaa.gov
#      ...                               ...
#      intake_esm_attrs:variable_id:     chl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM...
#      intake_esm_attrs:version:         20180701
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr,
#  'OMIP.NOAA-GFDL.GFDL-OM4p5B.omip1.Omon.gr': <xarray.Dataset>
#  Dimensions:         (member_id: 1, dcpp_init_year: 1, time: 3600, lev: 35,
#                       lat: 180, lon: 360, bnds: 2)
#  Coordinates:
#    * lat             (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#      lat_bnds        (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#    * lev             (lev) float64 2.5 10.0 20.0 32.5 ... 5.5e+03 6e+03 6.5e+03
#      lev_bnds        (lev, bnds) float64 dask.array<chunksize=(35, 2), meta=np.ndarray>
#    * lon             (lon) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#      lon_bnds        (lon, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#    * time            (time) object 1708-01-16 12:00:00 ... 2007-12-16 12:00:00
#      time_bnds       (time, bnds) object dask.array<chunksize=(3600, 2), meta=np.ndarray>
#    * member_id       (member_id) object 'r1i1p1f1'
#    * dcpp_init_year  (dcpp_init_year) float64 nan
#  Dimensions without coordinates: bnds
#  Data variables:
#      chl             (member_id, dcpp_init_year, time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 24, 35, 180, 360), meta=np.ndarray>
#  Attributes: (12/60)
#      Conventions:                      CF-1.7 CMIP-6.0 UGRID-1.0
#      activity_id:                      OMIP
#      branch_method:                    none provided
#      branch_time_in_child:             0.0
#      comment:                          Experiment name = OM4p5_IAF_BLING_CFC_a...
#      contact:                          gfdl.climate.model.info@noaa.gov
#      ...                               ...
#      intake_esm_attrs:variable_id:     chl
#      intake_esm_attrs:grid_label:      gr
#      intake_esm_attrs:zstore:          gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-OM...
#      intake_esm_attrs:version:         20180701
#      intake_esm_attrs:_data_format_:   zarr
#      intake_esm_dataset_key:           OMIP.NOAA-GFDL.GFDL-OM4p5B.omip1.Omon.gr}

# %%
[key for key in dset_dict.keys()][:10]
# Out:
# ['OMIP.NCAR.CESM2.omip1.Omon.gr',
#  'OMIP.NCAR.CESM2.omip1.Omon.gn',
#  'OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr',
#  'OMIP.NOAA-GFDL.GFDL-OM4p5B.omip1.Omon.gr']

# %%
dset_dict['OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr']
# Out:
# <xarray.Dataset>
# Dimensions:         (member_id: 1, dcpp_init_year: 1, time: 3600, lev: 35,
#                      lat: 180, lon: 360, bnds: 2)
# Coordinates:
#   * lat             (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     lat_bnds        (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#   * lev             (lev) float64 2.5 10.0 20.0 32.5 ... 5.5e+03 6e+03 6.5e+03
#     lev_bnds        (lev, bnds) float64 dask.array<chunksize=(35, 2), meta=np.ndarray>
#   * lon             (lon) float64 0.5 1.5 2.5 3.5 ... 356.5 357.5 358.5 359.5
#     lon_bnds        (lon, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#   * time            (time) object 1708-01-16 12:00:00 ... 2007-12-16 12:00:00
#     time_bnds       (time, bnds) object dask.array<chunksize=(3600, 2), meta=np.ndarray>
#   * member_id       (member_id) object 'r1i1p1f1'
#   * dcpp_init_year  (dcpp_init_year) float64 nan
# Dimensions without coordinates: bnds
# Data variables:
#     chl             (member_id, dcpp_init_year, time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 24, 35, 180, 360), meta=np.ndarray>
# Attributes: (12/60)
#     Conventions:                      CF-1.7 CMIP-6.0 UGRID-1.0
#     activity_id:                      OMIP
#     branch_method:                    none provided
#     branch_time_in_child:             0.0
#     comment:                          Experiment name = OM4p25_IAF_BLING_csf_...
#     contact:                          gfdl.climate.model.info@noaa.gov
#     ...                               ...
#     intake_esm_attrs:variable_id:     chl
#     intake_esm_attrs:grid_label:      gr
#     intake_esm_attrs:zstore:          gs://cmip6/CMIP6/OMIP/NOAA-GFDL/GFDL-CM...
#     intake_esm_attrs:version:         20180701
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr

# %%
dset_dict['OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr'].chl.isel(time=1200, lev=0).plot()

# %%
import dask

dask.config.set(scheduler='threads')
dask.config.set(num_workers=14)  # Adjust based on your CPU cores


#cesm_data_path = "http://thredds.atmos.albany.edu:8080/thredds/dodsC/CESMA/"
#atm_control = xr.open_dataset(cesm_data_path + "cpl_1850_f19/concatenated/cpl_1850_f19.cam.h0.nc")

#weight_factor = atm_control.gw / atm_control.gw.mean(dim='lat')

testplotdata = (dset_dict['OMIP.NOAA-GFDL.GFDL-CM4.omip1.Omon.gr'].chl.isel(lev=0)).mean(dim=('lat','lon')).groupby('time.year').mean()
testplotdata
# Out:
# <xarray.DataArray 'chl' (member_id: 1, dcpp_init_year: 1, year: 300)>
# dask.array<transpose, shape=(1, 1, 300), dtype=float32, chunksize=(1, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#     lev             float64 2.5
#   * member_id       (member_id) object 'r1i1p1f1'
#   * dcpp_init_year  (dcpp_init_year) float64 nan
#   * year            (year) int64 1708 1709 1710 1711 ... 2004 2005 2006 2007

# %%
testplotdata.plot()
